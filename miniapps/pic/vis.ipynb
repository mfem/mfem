# %%
# Read PIC_Part_*.csv (columns: id,rank,X,Y), plot scatter for each file and create a video.
# Parallel frame render + ffmpeg stitch. Saves PIC_animation.mp4 and displays it.

import glob
import os
import re
import shutil
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed
from pathlib import Path

import matplotlib
matplotlib.use("Agg")
import numpy as np
import pandas as pd
from IPython.display import Video, display
from tqdm import tqdm

from xy_render_worker import render_one_frame

PATTERN = "PIC_Part_*.csv"
OUT_MP4 = "PIC_animation.mp4"
FPS = 10
DPI = 150
SCATTER_SIZE = 8
N_WORKERS = max(1, (os.cpu_count() or 4) - 1)
FRAME_CACHE_DIR = Path("_xy_frame_cache")


def extract_step(path: Path) -> int:
    m = re.search(r"PIC_Part_(\d+)\.csv$", path.name)
    return int(m.group(1)) if m else -1


def padded_lim(vals: np.ndarray) -> tuple[float, float]:
    pad = (vals.max() - vals.min()) * 0.02 if np.ptp(vals) != 0 else 1.0
    return float(vals.min() - pad), float(vals.max() + pad)


def list_snapshot_files(pattern: str = PATTERN) -> list[Path]:
    files = sorted(glob.glob(pattern), key=lambda f: extract_step(Path(f)))
    if not files:
        raise FileNotFoundError(f"No files matching pattern: {pattern}")
    return [Path(f) for f in files]


def load_frames(files: list[Path]) -> list[pd.DataFrame]:
    required = {"id", "rank", "X", "Y"}
    frames = []
    for f in tqdm(files, desc="Reading CSV frames"):
        df = pd.read_csv(f, usecols=list(required))
        if not required.issubset(df.columns):
            raise ValueError(f"{f} missing required columns. Found: {list(df.columns)}")
        frames.append(df)
    return frames


def prepare_frame_arrays(frames: list[pd.DataFrame]) -> tuple[list[dict], tuple, tuple, tuple]:
    all_x = np.concatenate([df["X"].to_numpy() for df in frames])
    all_y = np.concatenate([df["Y"].to_numpy() for df in frames])
    all_ranks = np.concatenate([df["rank"].to_numpy() for df in frames])
    xlim = padded_lim(all_x)
    ylim = padded_lim(all_y)
    rank_lim = (float(np.min(all_ranks)), float(np.max(all_ranks)))

    compact = []
    for df in frames:
        compact.append(
            {
                "x": df["X"].to_numpy(dtype=np.float32, copy=False),
                "y": df["Y"].to_numpy(dtype=np.float32, copy=False),
                "rank": df["rank"].to_numpy(dtype=np.float32, copy=False),
            }
        )
    return compact, xlim, ylim, rank_lim


def render_animation_parallel(
    frames: list[dict],
    files: list[Path],
    xlim,
    ylim,
    rank_lim,
    out_mp4: str = OUT_MP4,
    fps: int = FPS,
    n_workers: int = N_WORKERS,
    cache_dir: Path = FRAME_CACHE_DIR,
) -> str:
    if cache_dir.exists():
        shutil.rmtree(cache_dir)
    png_dir = cache_dir / "png"
    npz_dir = cache_dir / "npz"
    png_dir.mkdir(parents=True)
    npz_dir.mkdir(parents=True)

    npz_paths = []
    png_paths = []
    for i, fr in enumerate(tqdm(frames, desc="Caching frame arrays")):
        npz_path = npz_dir / f"frame_{i:06d}.npz"
        png_path = png_dir / f"frame_{i:06d}.png"
        np.savez_compressed(npz_path, x=fr["x"], y=fr["y"], rank=fr["rank"])
        npz_paths.append(npz_path)
        png_paths.append(png_path)

    n_frames = len(frames)
    tasks = [
        (
            i,
            str(npz_paths[i]),
            str(png_paths[i]),
            xlim,
            ylim,
            rank_lim,
            f"Frame {i + 1}/{n_frames}  —  {files[i].name}",
            DPI,
            SCATTER_SIZE,
        )
        for i in range(n_frames)
    ]

    print(f"Rendering {n_frames} frames with {n_workers} workers...")
    with ProcessPoolExecutor(max_workers=n_workers) as ex:
        futs = [ex.submit(render_one_frame, t) for t in tasks]
        for fut in tqdm(as_completed(futs), total=len(futs), desc="Rendering frames"):
            fut.result()

    cmd = [
        "ffmpeg", "-y",
        "-framerate", str(fps),
        "-i", str(png_dir / "frame_%06d.png"),
        "-vf", "scale=trunc(iw/2)*2:trunc(ih/2)*2",
        "-c:v", "libx264",
        "-pix_fmt", "yuv420p",
        "-crf", "23",
        out_mp4,
    ]
    try:
        subprocess.run(cmd, check=True, capture_output=True, text=True)
    except FileNotFoundError as e:
        raise RuntimeError("ffmpeg not found on PATH; required to stitch PNGs into MP4.") from e
    except subprocess.CalledProcessError as e:
        raise RuntimeError(f"ffmpeg failed:\n{e.stderr}") from e

    shutil.rmtree(cache_dir, ignore_errors=True)
    return out_mp4


files = list_snapshot_files(PATTERN)
frames = load_frames(files)
compact, xlim, ylim, rank_lim = prepare_frame_arrays(frames)
saved_path = render_animation_parallel(compact, files, xlim, ylim, rank_lim)

display(Video(saved_path, embed=True))
print(f"Saved animation to: {saved_path}")
